# %%
from __future__ import division

# %%
import h5py as h5

# %%
f = h5.File("lines.h5", "r")

# %%
nu = f["Traces"]["nu"]
T = f["Traces"]["T"]
chisq = f["Probability"]["probability"]

# %%
# Set burn in
i = arange(nu.size)
burn_in = 0
i = i[burn_in:]
nu = nu[burn_in:]
T = T[burn_in:]

# %%
dnu = loadtxt("data/spectral.dat", usecols=[0])
dT = loadtxt("data/spectral.dat", usecols=[1])
fi = exp(-(dnu - 37)**2 / (2*2**2))
sumdifi = (dT*fi).sum()
sumfi = (fi**2).sum()

# %%
def t_post(T):
    return (1/T) * exp(T*sumdifi)*exp(-(T**2*sumfi)/2)

# %%
t = arange(0.1, 3.5, 0.1)
plot(t, t_post(t))

# %%
plot(i[::50], nu[::50])
xlabel("iteration")
ylabel(r"$\nu$")

# %%
plot(i[::50], T[::50])

# %%
scatter(nu[::20], T[::20])
xlabel("iteration")
ylabel("T")

# %%
a = hist(nu, normed=True, bins=46)
xlabel(r"$\nu$")

# %%
a = hist(T, normed=True, bins=46) 
xlabel("T")

# %%
plot(chisq[0:5000])
